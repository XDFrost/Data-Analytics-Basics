# %% [markdown]
# - Data is initially in the form of 2-D array

# %%
a = ['Delhi', 162, 200, 150], ['Chandigarh', 180, 227, 115], ['Shimla', 200, 115, 310]

# %%
for i in a: print(i)
# Out:
# ['Delhi', 162, 200, 150]
# ['Chandigarh', 180, 227, 115]
# ['Shimla', 200, 115, 310]

# %%
print(a)
print(type(a))
# Out:
# (['Delhi', 162, 200, 150], ['Chandigarh', 180, 227, 115], ['Shimla', 200, 115, 310])
# <class 'tuple'>

# %%
b = 1,2,3

# %%
print(b)
print(type(b))
# Out:
# (1, 2, 3)
# <class 'tuple'>

# %%
b = [[162,200,150], [180,220,115], [200,115,310]]

# %%
print(b)
print(type(b))
# Out:
# [[162, 200, 150], [180, 220, 115], [200, 115, 310]]
# <class 'list'>

# %% [markdown]
# ###

# %% [markdown]
# ## Numpy

# %%
import numpy as np

# %%
np.array([1,2,3,4,5])              # array function converts any mentioned data type into array
# Out:
# array([1, 2, 3, 4, 5])

# %%
a = [2,234,45,456,324,67,567,567,567]
type(a)
# Out:
# list

# %%
arr = np.array(a)

# %%
print(a)
# Out:
# [2, 234, 45, 456, 324, 67, 567, 567, 567]

# %%
arr
# Out:
# array([  2, 234,  45, 456, 324,  67, 567, 567, 567])

# %%
b
# Out:
# [[162, 200, 150], [180, 220, 115], [200, 115, 310]]

# %%
twoDarr = np.array(b)

# %%
twoDarr                # Let's say rows are states and columns are months
# Out:
# array([[162, 200, 150],
#        [180, 220, 115],
#        [200, 115, 310]])

# %%
import pandas as pd

# %%
df = pd.DataFrame(twoDarr)
df
# Out:
#      0    1    2
# 0  162  200  150
# 1  180  220  115
# 2  200  115  310

# %%
df = pd.DataFrame(twoDarr, index=[i[0] for i in a], columns=['June', 'July', 'August'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\PYTHON\Data Analytics\College\Lecture_2_Numpy_intro.ipynb Cell 22 in 1
# ----> <a href='vscode-notebook-cell:/d%3A/PYTHON/Data%20Analytics/College/Lecture_2_Numpy_intro.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> df = pd.DataFrame(twoDarr, index=[i[0] for i in a], columns=['June', 'July', 'August'])
#
# d:\PYTHON\Data Analytics\College\Lecture_2_Numpy_intro.ipynb Cell 22 in 1
# ----> <a href='vscode-notebook-cell:/d%3A/PYTHON/Data%20Analytics/College/Lecture_2_Numpy_intro.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> df = pd.DataFrame(twoDarr, index=[i[0] for i in a], columns=['June', 'July', 'August'])
#
# TypeError: 'int' object is not subscriptable

# %%
df
# Out:
#             June  July  August
# Delhi        162   200     150
# Chandigarh   180   220     115
# Shimla       200   115     310

# %%
li = df.index.values
for i in li: print(i)
# Out:
# Delhi
# Chandigarh
# Shimla

# %%
li = df.columns.values 
for i in li: print(i)
# Out:
# June
# July
# August

# %%
df['June']                           # Provides all info in the month of june
# Out:
# Delhi         162
# Chandigarh    180
# Shimla        200
# Name: June, dtype: int32

# %%
df.iloc[0]
# Out:
# 0    162
# 1    200
# 2    150
# Name: 0, dtype: int32

# %%
df.loc['Chandigarh']                 # loc function locates a specific element values into data set; loc is for getting row elements
# Out:
# June      180
# July      220
# August    115
# Name: Chandigarh, dtype: int32

# %%
rain_den_in_june = df['June']

# %%
rain_den_in_june
# Out:
# Delhi         162
# Chandigarh    180
# Shimla        200
# Name: June, dtype: int32

# %%
type(rain_den_in_june)
# Out:
# pandas.core.series.Series

# %%
l2 = list(rain_den_in_june)

# %%
l2
# Out:
# [162, 180, 200]

# %%
li = np.array(rain_den_in_june)

# %%
li
# Out:
# array([162, 180, 200])

# %%
rain_den_in_june['Chandigarh']                  # will provide the corresponding value with respect to the key
# Out:
# 180

# %% [markdown]
# ###

# %% [markdown]
# - All keys in a dictionary will be column name for a dataset
#
# - Numeric data is automatically converted into float type
#
# - Columns that are able to categorise the rows into a few parts is called categorial column
#
# - Columns that are contains numeral values are called numerical columns
#
# - Columns that are contains string values are called string columns

# %% [markdown]
# ###

# %%
mydata = {'Rollno.':10, 'Name':'Amit', 'Gender':'Male'}, {'empid':11, 'Name':'Priya', 'Gender': 'Female'}, {'Rollno.':10, 'Name':'Amit1', 'Gender':'Male'}, {'empid':11, 'Name':'Priya1', 'Gender': 'Female'}

# %%
pd.DataFrame(mydata)                 # since no empid value is provided to amit, dataset will set it as null by default
# Out:
#    Rollno.    Name  Gender  empid
# 0     10.0    Amit    Male    NaN
# 1      NaN   Priya  Female   11.0
# 2     10.0   Amit1    Male    NaN
# 3      NaN  Priya1  Female   11.0
