# %%
from google.colab import drive                  # We can access data from google colab
drive.mount("/content/drive")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\PYTHON\Data Analytics\College\Lecture_5_Intro_to_GoogleColab.ipynb Cell 1 in 1
# ----> <a href='vscode-notebook-cell:/d%3A/PYTHON/Data%20Analytics/College/Lecture_5_Intro_to_GoogleColab.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from google.colab import drive                  # We can access data from google colab
#       <a href='vscode-notebook-cell:/d%3A/PYTHON/Data%20Analytics/College/Lecture_5_Intro_to_GoogleColab.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> drive.mount("/content/drive")
#
# File d:\PYTHON\Python Interface\lib\site-packages\google\colab\__init__.py:23
#      21 from google.colab import _installation_commands
#      22 from google.colab import _shell_customizations
# ---> 23 from google.colab import _system_commands
#      24 from google.colab import _tensorflow_magics
#      25 from google.colab import auth
#
# ...

# %% [markdown]
# - We'll only be able to see data from drive after we mount it

# %% [markdown]
# ###

# %% [markdown]
# import pandas as pd

# %% [markdown]
# - pd.read_excel('content/folder_name or file_name/file_name')
#
#     this above commands reads file data that's mentioned

# %% [markdown]
# ###

# %% [markdown]
# df.info()
#
# - Gives the info about data in data frame e.g. non-nan values
